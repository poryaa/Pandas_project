# %% [markdown]
# ## Reading In Files

# %%
import pandas as pd

# %% [markdown]
# testing complete

# %%
df = pd.read_csv('countries of the world.csv')
df.head()

# %%
df = pd.read_table('countries of the world.txt')
df.head()

# %%
df = pd.read_json('json_sample.json')
df.head()

# %%
df = pd.read_excel('world_population_excel_workbook.xlsx',sheet_name='Sheet1')
df.head()

# %%
df.info()

# %% [markdown]
# ## Filtering Columns and Rows in Pandas | Python Pandas Tutorials

# %%
import pandas as pd

# %%
df = pd.read_excel('world_population_excel_workbook.xlsx')
df.head()

# %%
df[df['Rank'] <= 10 ]

# %%
specific_countries = ['Bangladesh','Brazil']
df[df["Country"].isin(specific_countries)]

# %%
df[df["Country"].str.contains('United')]

# %%
df2 = df.set_index('Country')
df2

# %%
df

# %%
df[df['Rank'] < 10].sort_values(by='Rank')

# %% [markdown]
# ## Indexes in Pandas | Python Pandas Tutorials

# %%
import pandas as pd

# %%
df = pd.read_excel('world_population_excel_workbook.xlsx', index_col='Country')
df.head()

# %%
df.reset_index(inplace=True)
df

# %%
df.set_index('Country', inplace=True)
df

# %%
df.iloc[1]

# %%
df.reset_index(inplace=True)

# %%
df.set_index(['Continent', 'Country'], inplace=True)
df

# %%
df.sort_index()

# %% [markdown]
# ## Group By and Aggregate Functions in Pandas | Python Pandas Tutorials

# %%
import pandas as pd

# %%
df = pd.read_csv('Flavors.csv')
df

# %%
group_by_frame = df.groupby('Base Flavor')

# %%
group_by_frame.mean(numeric_only=True)

# %%
group_by_frame.max()

# %%
df.groupby('Base Flavor').agg({'Flavor Rating': ['min','max','count','sum']})

# %%
df.groupby(['Base Flavor','Liked']).mean(numeric_only=True)

# %% [markdown]
# ## Merging DataFrames in Pandas | Python Pandas Tutorials

# %%
import pandas as pd

# %%
df1 = pd.read_csv('data/LOTR.csv')
df2 = pd.read_csv('data/LOTR 2.csv')

# %%
df1.info(),df2.info()

# %%
df1.merge(df2, how='inner')

# %%
df1.merge(df2, how='inner', on='FellowshipID')

# %%
df1.merge(df2, how='outer')

# %%
df1.merge(df2, how='left')

# %%
df1.join(df2, on='FellowshipID', how='outer', lsuffix='_Left',rsuffix='_Right')

# %%
df4 =df1.set_index('FellowshipID').join(df2.set_index('FellowshipID'), lsuffix='_Left',rsuffix='_Right',how='outer')
df4

# %%
pd.concat([df1,df2])

# %% [markdown]
# ## Creating Visualizations using Pandas Library | Python Pandas Tutorials

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/Ice Cream Ratings.csv')
df

# %%
df.set_index('Date')

# %%
df.plot(kind='line',title='Ice Cream Ratings', xlabel="Daily Rating", ylabel='Scores')

# %%
df.plot(kind='bar',title='Ice Cream Ratings', xlabel="Daily Rating", ylabel='Scores',stacked=True)

# %%
df['Flavor Rating'].plot(kind='barh',title='Ice Cream Ratings', xlabel="Daily Rating", ylabel='Scores')

# %%
df.plot.scatter(x='Texture Rating',y='Overall Rating',s=100, c='y')

# %%
df.plot.hist(bins=20)

# %%
df.boxplot()

# %%
df.plot.area(figsize=(10,5))

# %%
print(plt.style.available)
plt.style.use('seaborn-v0_8-dark-palette')

# %% [markdown]
# ## Data Cleaning in Pandas | Python Pandas Tutorials

# %%
import pandas as pd

# %%
df = pd.read_excel('data/Customer Call List.xlsx')
df.head()

# %%
df.drop_duplicates(inplace=True)

# %%
#drop last column
df.drop(columns=['Not_Useful_Column'], inplace=True)

# %%
#clean a column from odd charachters(/,.,...)
df["Last_Name"] = df['Last_Name'].str.strip("123._/")
df

# %%
df['Phone_Number']

# %%
#replcae all charachtesr except a-z and numbers with '' with regex
df['Phone_Number'] = df['Phone_Number'].str.replace('[^a-zA-Z0-9]','', regex=True)
df

# %%
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: str(x))
df['Phone_Number'] = df['Phone_Number'].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
df['Phone_Number'] = df['Phone_Number'].str.replace('nan--', '')
df['Phone_Number'] = df['Phone_Number'].str.replace('Na--', '')
df

# %%
df[['Street_Address', 'State', 'Zip_Code']] = df["Address"].str.split(',',n=2, expand=True)
df

# %%
df['Paying Customer'] = df['Paying Customer'].str.replace('Yes', 'Y')
df['Paying Customer'] = df['Paying Customer'].str.replace('No', 'N')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('Yes', 'Y')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('No', 'N')
df

# %%
df = df.fillna('')
df['Paying Customer'] = df['Paying Customer'].str.replace('N/a', '')
df['Do_Not_Contact'] = df['Do_Not_Contact'].str.replace('NaN', '')
df

# %%
for x in df.index:
    if df.loc[x, "Do_Not_Contact"] == 'Y':
        df.drop(x, inplace=True)
df

# %%
for x in df.index:
    if df.loc[x, "Phone_Number"] == '':
        df.drop(x, inplace=True)
df

# %%
df.reset_index()

# %%
df.drop(columns=['index'])

# %%
df

# %% [markdown]
# ## Exploratory Data Analysis in Pandas | Python Pandas Tutorials

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/world_population.csv')
df

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df.nunique()

# %%
df.sort_values(by='2022 Population', ascending=False).head()

# %%
df.corr(numeric_only=True)

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.rcParams['figure.figsize']=(20,7)
plt.show()

# %%
df2 = df.groupby('Continent').mean(numeric_only=True).sort_values(by='2022 Population')

# %%
df.columns

# %%
df2 = df.groupby('Continent')[df.columns[5:13]].mean(numeric_only=True).sort_values(by='2022 Population')

# %%
df3=df2.transpose()
df3.plot()

# %%
df3.boxplot()

# %%
df.dtypes
